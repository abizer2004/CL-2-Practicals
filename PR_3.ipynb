# %%
pip install pgmpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pgmpy in c:\users\admin\appdata\roaming\python\python312\site-packages (1.0.0)
# Requirement already satisfied: networkx in d:\programdata\anacondanavigator\lib\site-packages (from pgmpy) (3.3)
# Requirement already satisfied: numpy in d:\programdata\anacondanavigator\lib\site-packages (from pgmpy) (1.26.4)
# Requirement already satisfied: scipy in d:\programdata\anacondanavigator\lib\site-packages (from pgmpy) (1.13.1)
# Requirement already satisfied: scikit-learn in d:\programdata\anacondanavigator\lib\site-packages (from pgmpy) (1.5.1)
# Requirement already satisfied: pandas in d:\programdata\anacondanavigator\lib\site-packages (from pgmpy) (2.2.2)
# Requirement already satisfied: torch in c:\users\admin\appdata\roaming\python\python312\site-packages (from pgmpy) (2.9.0)
# Requirement already satisfied: statsmodels in d:\programdata\anacondanavigator\lib\site-packages (from pgmpy) (0.14.2)
# Requirement already satisfied: tqdm in d:\programdata\anacondanavigator\lib\site-packages (from pgmpy) (4.66.5)
# Requirement already satisfied: joblib in d:\programdata\anacondanavigator\lib\site-packages (from pgmpy) (1.4.2)
# Requirement already satisfied: opt-einsum in c:\users\admin\appdata\roaming\python\python312\site-packages (from pgmpy) (3.4.0)
# Requirement already satisfied: pyro-ppl in c:\users\admin\appdata\roaming\python\python312\site-packages (from pgmpy) (1.9.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\programdata\anacondanavigator\lib\site-packages (from pandas->pgmpy) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\programdata\anacondanavigator\lib\site-packages (from pandas->pgmpy) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\programdata\anacondanavigator\lib\site-packages (from pandas->pgmpy) (2023.3)
# Requirement already satisfied: pyro-api>=0.1.1 in c:\users\admin\appdata\roaming\python\python312\site-packages (from pyro-ppl->pgmpy) (0.1.2)
# Requirement already satisfied: filelock in d:\programdata\anacondanavigator\lib\site-packages (from torch->pgmpy) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in d:\programdata\anacondanavigator\lib\site-packages (from torch->pgmpy) (4.11.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\admin\appdata\roaming\python\python312\site-packages (from torch->pgmpy) (1.14.0)
# Requirement already satisfied: jinja2 in d:\programdata\anacondanavigator\lib\site-packages (from torch->pgmpy) (3.1.4)
# Requirement already satisfied: fsspec>=0.8.5 in d:\programdata\anacondanavigator\lib\site-packages (from torch->pgmpy) (2024.6.1)
# Requirement already satisfied: setuptools in d:\programdata\anacondanavigator\lib\site-packages (from torch->pgmpy) (75.1.0)
# Requirement already satisfied: colorama in c:\users\admin\appdata\roaming\python\python312\site-packages (from tqdm->pgmpy) (0.4.6)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\programdata\anacondanavigator\lib\site-packages (from scikit-learn->pgmpy) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in d:\programdata\anacondanavigator\lib\site-packages (from statsmodels->pgmpy) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in d:\programdata\anacondanavigator\lib\site-packages (from statsmodels->pgmpy) (24.1)
# Requirement already satisfied: six in d:\programdata\anacondanavigator\lib\site-packages (from patsy>=0.5.6->statsmodels->pgmpy) (1.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\programdata\anacondanavigator\lib\site-packages (from sympy>=1.13.3->torch->pgmpy) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\programdata\anacondanavigator\lib\site-packages (from jinja2->torch->pgmpy) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd

# %%
from pgmpy.models import DiscreteBayesianNetwork
from pgmpy.estimators import MaximumLikelihoodEstimator
from pgmpy.inference import VariableElimination

# %%
# Read Cleveland Heart Disease data 
heartDisease = pd.read_csv("C:/Users/Admin/Downloads/heart.csv")

# %%
heartDisease.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   age           303 non-null    int64
#  1   sex           303 non-null    int64
#  2   cp            303 non-null    int64
#  3   trestbps      303 non-null    int64
#  4   chol          303 non-null    int64
#  5   fbs           303 non-null    int64
#  6   restecg       303 non-null    int64
#  7   thalach       303 non-null    int64
#  8   exang         303 non-null    int64
#  9   oldpeak       303 non-null    float64
#  10  slope         303 non-null    int64
#  11  ca            303 non-null    object
#  12  thal          303 non-null    object
#  13  heartdisease  303 non-null    int64
# dtypes: float64(1), int64(11), object(2)
# memory usage: 33.3+ KB

# %%
heartDisease = heartDisease.replace('?', np.nan)

# %%
# Model Bayesian Network
model = DiscreteBayesianNetwork([('age','trestbps'),('age','fbs'),('sex','trestbps'),('exang','trestbps'),('trestbps','heartdisease'),
                       ('fbs','heartdisease'),('heartdisease','restecg'), ('heartdisease','thalach'),('heartdisease','chol')])

# %%
# Learning CPDs using Maximum Likelihood Estimators
print('\nLearning CPD using Maximum likelihood estimators')
model.fit(heartDisease, estimator=MaximumLikelihoodEstimator)
# Out:
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'age': 'N', 'sex': 'N', 'cp': 'N', 'trestbps': 'N', 'chol': 'N', 'fbs': 'N', 'restecg': 'N', 'thalach': 'N', 'exang': 'N', 'oldpeak': 'N', 'slope': 'N', 'ca': 'C', 'thal': 'C', 'heartdisease': 'N'}
# Learning CPD using Maximum likelihood estimators

# %%
# Inferencing with Bayesian Network 
print('Inferencing with Bayesian Network:') 
HeartDisease_infer = VariableElimination(model)

# Probability of HeartDisease given Age = 38
print('1. Probability of HeartDisease given Age=38') 
q1 = HeartDisease_infer.query(variables=['heartdisease'], evidence={'age':38})
print(q1)

# Probability of HeartDisease given cholesterol 
print('\n 2. Probability of HeartDisease given cholesterol=230') 
q=HeartDisease_infer.query(variables=['heartdisease'], evidence ={'chol':230})
print(q)
# Out:
# Inferencing with Bayesian Network:
# 1. Probability of HeartDisease given Age=38
# +-----------------+---------------------+
# | heartdisease    |   phi(heartdisease) |
# +=================+=====================+
# | heartdisease(0) |              0.7026 |
# +-----------------+---------------------+
# | heartdisease(1) |              0.1024 |
# +-----------------+---------------------+
# | heartdisease(2) |              0.0577 |
# +-----------------+---------------------+
# | heartdisease(3) |              0.0631 |
# +-----------------+---------------------+
# | heartdisease(4) |              0.0741 |
# +-----------------+---------------------+
#
#  2. Probability of HeartDisease given cholesterol=230
# +-----------------+---------------------+
# | heartdisease    |   phi(heartdisease) |
# +=================+=====================+
# | heartdisease(0) |              0.0000 |
# +-----------------+---------------------+
# | heartdisease(1) |              0.3270 |
# +-----------------+---------------------+
# | heartdisease(2) |              0.3059 |
# +-----------------+---------------------+
# | heartdisease(3) |              0.0000 |
# +-----------------+---------------------+
# | heartdisease(4) |              0.3671 |
# +-----------------+---------------------+
